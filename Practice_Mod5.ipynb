# %%
from collections import Counter

s = input().strip()
freq = Counter(s)
print(freq)

for ch in sorted(freq):
    print(f"{ch} : {freq[ch]}")
# Out:
#  aabsc
# Counter({'a': 2, 'b': 1, 's': 1, 'c': 1})
# a : 2
# b : 1
# c : 1
# s : 1

# %%
from collections import Counter
s=input().strip()
freq=Counter(s)

for ch in sorted(freq):
    print(f"{ch} : {freq[ch]}")
# Out:
#   Cell In[3], line 5
#     for ch in sorted(freq):
#                            ^
# _IncompleteInputError: incomplete input

# %%
n,m=input().split()
arr=list(map(int, input().split()))
a=set(map(int,input().split()))
b=set(map(int,input().split()))
h=0
for x in arr:
    if x in a:
        h+=1
    elif x in b:
        h-=1
print(h)
